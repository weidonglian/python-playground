# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 1
a, b, c ,d
# Out:
# (1, 2, 4, 8)

# %%
import matplotlib.pyplot as plt

plt.plot([a, b, c, d])
plt.show()

# %% [markdown]
# # This is a special learning hello-world
#
# - hello
# - world
