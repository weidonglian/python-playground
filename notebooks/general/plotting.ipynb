# %% [markdown]
# # Plotting
#
# ## Draw a simple exponential curve

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the vectors X and Y
exponent = -1.5
const_exp = 0.77686983985157021
x = np.array(range(0, 60))
y = (1.0 - np.exp(exponent * x / 60)) / const_exp

# Create the plot
plt.plot(x, y)

# Show the plot
plt.show()

# %% [markdown]
# ## Draw a normalized curve

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the array x random between 0 and 1000
x = np.random.randint(0, 1000, 100)
plt.plot(x)
plt.show()

# %%
# Normalize the array x with min-max normalization
x_norm = (x - x.min()) / (x.max() - x.min())
plt.plot(x_norm)
plt.show()

# %%
# Normalize the array x with gaussian normalization
print(f'mean: {x.mean()} and std: {x.std()}')
x_norm = (x - x.mean()) / x.std()
plt.plot(x_norm)
plt.show()

# %% [markdown]
# ## Draw a simple gradient curve

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the vectors X and Y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
F = np.sin(X) + np.cos(Y)

grad_F_x, grad_F_y = np.gradient(F, x, y)

plt.quiver(x, y, grad_F_x, grad_F_y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numerical Gradient Vector Field')
plt.show()
